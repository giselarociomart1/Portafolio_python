# %% [markdown]
# # Desafío - Manipulación y transformación de datos (Parte I)

# %% [markdown]
# 1. Para desarrollar este desafío necesitarás los siguientes archivos:
# ● incidents.pkl
# ● officers.pkl
# ● subjects.pkl
# a. Carga los datos y crea un DataFrame con cada uno de ellos.

# %%
# Primero importamos la librería pandas.
import pandas as pd

# Ahora cargamos las bases de datos y las volvemos dataframes.
incidents= pd.read_pickle("incidents.pkl")
officers= pd.read_pickle("officers.pkl")
subjects= pd.read_pickle("subjects.pkl")

# %% [markdown]
# b. Genera una tabla que contenga la unión de las 3 tablas.

# %%
# Para poder saber cómo ralizar la union vamos a  ver los nombres de las columnas.
incidents.columns
# Out:
# Index(['case_number', 'date', 'location', 'subject_statuses', 'subject_weapon',
#        'subjects', 'subject_count', 'officers', 'officer_count',
#        'grand_jury_disposition', 'attorney_general_forms_url', 'summary_url',
#        'summary_text', 'latitude', 'longitude'],
#       dtype='object')

# %%
officers.columns
# Out:
# Index(['case_number', 'race', 'gender', 'last_name', 'first_name',
#        'full_name'],
#       dtype='object')

# %%
subjects.columns
# Out:
# Index(['case_number', 'race', 'gender', 'last_name', 'first_name',
#        'full_name'],
#       dtype='object')

# %%
# Realizamos la union las 3 tabla y agregamos sufijos para distinguir las columnas que se llaman igual.
# Lo voy a hacer en dos partes para no perder la información del sufijo.

union_parcial = incidents.merge(officers, on='case_number', how='inner', suffixes=("_inc", "_off"))
union_final = union_parcial.merge(subjects, on='case_number', how='inner', suffixes=(None, "_sub"))

#Imprimimos el resultado.
union_final
# Out:
#      case_number        date                  location subject_statuses  \
# 0         44523A  2013-02-23     3000 Chihuahua Street          Injured
# 1         44523A  2013-02-23     3000 Chihuahua Street          Injured
# 2        121982X  2010-05-03  1300 N. Munger Boulevard          Injured
# 3        605484T  2007-08-12   200 S. Stemmons Freeway            Other
# 4        384832T  2007-05-26           7900 S. Loop 12   Shoot and Miss
# ..           ...         ...                       ...              ...
# 372  165193-2016  2016-07-07           801 Main Street         Deceased
# 373  165193-2016  2016-07-07           801 Main Street         Deceased
# 374  165193-2016  2016-07-07           801 Main Street         Deceased
# 375  165193-2016  2016-07-07           801 Main Street         Deceased
# 376  165193-2016  2016-07-07           801 Main Street         Deceased
#
#     subject_weapon                                           subjects  \
# 0          Handgun                                   Curry, James L/M
# 1          Handgun                                   Curry, James L/M
# 2          Handgun                                Chavez, Gabriel L/M
# 3          Shotgun                                  Salinas, Nick L/M
# 4          Unarmed  Smith, James B/M; Dews, Antonio B/M; Spearman,...
# ..             ...                                                ...
# 372  Assault Rifle                                 Johnson, Micah B/M
# 373  Assault Rifle                                 Johnson, Micah B/M
# 374  Assault Rifle                                 Johnson, Micah B/M
# 375  Assault Rifle                                 Johnson, Micah B/M
# 376  Assault Rifle                                 Johnson, Micah B/M
#
#      subject_count                                           officers  \
# 0                1          Patino, Michael L/M; Fillingim, Brian W/M
# 1                1          Patino, Michael L/M; Fillingim, Brian W/M
# 2                1                               Padilla, Gilbert L/M
# 3                1                                  Poston, Jerry W/M
# 4                3                                 Mondy, Michael B/M
# ..             ...                                                ...
# 372              1  Edwards, Henry W/M; Wells, Giovanni B/M; Junge...
# 373              1  Edwards, Henry W/M; Wells, Giovanni B/M; Junge...
# 374              1  Edwards, Henry W/M; Wells, Giovanni B/M; Junge...
# 375              1  Edwards, Henry W/M; Wells, Giovanni B/M; Junge...
# 376              1  Edwards, Henry W/M; Wells, Giovanni B/M; Junge...
#
#      officer_count grand_jury_disposition  ... race gender  last_name  \
# 0                2                No Bill  ...    L      M     Patino
# 1                2                No Bill  ...    W      M  Fillingim
# 2                1                No Bill  ...    L      M    Padilla
# 3                1            See Summary  ...    W      M     Poston
# 4                1                   None  ...    B      M      Mondy
# ..             ...                    ...  ...  ...    ...        ...
# 372             12                   None  ...    W      M   Michaels
# 373             12                   None  ...    W      M  Borchardt
# 374             12                   None  ...    W      M      Craig
# 375             12                   None  ...    W      M     Cannon
# 376             12                   None  ...    B      M     Stuart
#
#      first_name           full_name race_sub gender_sub last_name_sub  \
# 0       Michael     Patino, Michael        L          M         Curry
# 1         Brian    Fillingim, Brian        L          M         Curry
# 2       Gilbert    Padilla, Gilbert        L          M        Chavez
# 3         Jerry       Poston, Jerry        L          M       Salinas
# 4       Michael      Mondy, Michael        B          M         Smith
# ..          ...                 ...      ...        ...           ...
# 372        Mark      Michaels, Mark        B          M       Johnson
# 373      Jeremy   Borchardt, Jeremy        B          M       Johnson
# 374      Robert       Craig, Robert        B          M       Johnson
# 375       Elmar       Cannon, Elmar        B          M       Johnson
# 376  Kristopher  Stuart, Kristopher        B          M       Johnson
#
#     first_name_sub    full_name_sub
# 0            James     Curry, James
# 1            James     Curry, James
# 2          Gabriel  Chavez, Gabriel
# 3             Nick    Salinas, Nick
# 4            James     Smith, James
# ..             ...              ...
# 372          Micah   Johnson, Micah
# 373          Micah   Johnson, Micah
# 374          Micah   Johnson, Micah
# 375          Micah   Johnson, Micah
# 376          Micah   Johnson, Micah
#
# [377 rows x 25 columns]

# %% [markdown]
# c. Verifica si hay filas duplicadas; si es así, elimínalas.

# %%
# Primero vamos a ver si hay filas duplicadas.
print(union_final.duplicated().sum())

# No hay filas duplicadas.
# Out:
# 0

# %% [markdown]
# d. ¿Cuántos sujetos de género F hay en el DataFrame resultante?

# %%
# Vamos a contar en la columna gender que tiene el sufijo "_sub".
conteo_f = union_final['gender_sub'].value_counts().get('F', 0)

#Imprimimos el resultado.
print(f"Número de sujetos de género 'F': {conteo_f}")
# Out:
# Número de sujetos de género 'F': 9

# %% [markdown]
# e. ¿En cuántos números de caso hay por lo menos una sospechosa que sea mujer?

# %%
# Filtramos el DataFrame para obtener solo las filas donde el género es 'F'.
casos_con_mujeres = union_final[union_final['gender_sub'] == 'F']

# Usamos unique() para obtener todos los 'case_number' únicos del resultado filtrado  y luego contar cuántos hay (usando len()).
numero_de_casos_unicos = len(casos_con_mujeres['case_number'].unique())

#Imprimimos el resultado.
print(f"Número de casos con por lo menos una sospechosa mujer: {numero_de_casos_unicos}")
# Out:
# Número de casos con por lo menos una sospechosa mujer: 7

# %% [markdown]
# f. Genera una tabla pivote que muestre en las filas el género del oficial y en las columnas el
# género del subject. ¿Cómo interpretas los valores que muestra esta vista?

# %%
# Generamos la tabla pivote.

pivot1 = pd.pivot_table(
    data=union_final,
    index='gender',
    columns='gender_sub',
    values='case_number',
    aggfunc='count'
)

#interpretación:
#Cada celda muestra cuántos casos hubo entre un tipo de oficial y un tipo de sujeto.

#Imprimimos el resultado.
pivot1
# Out:
# gender_sub  F    M
# gender
# F           2   18
# M           7  350

# %% [markdown]
# 2. Para continuar con el desarrollo de este desafío, necesitarás el archivo "Cleaned_DS_Jobs.csv"
# a. Carga los datos y crea un DataFrame con ellos.

# %%
# Cargamos los datos y creamos el dataframe.
df= pd.read_csv("Cleaned_DS_Jobs.csv")

# Visualizamos el dataframe creado.
df
# Out:
#              Job Title Salary Estimate  \
# 0    Sr Data Scientist        137-171
# 1       Data Scientist        137-171
# 2       Data Scientist        137-171
# 3       Data Scientist        137-171
# 4       Data Scientist        137-171
# ..                 ...             ...
# 655     Data Scientist        105-167
# 656     Data Scientist        105-167
# 657     Data Scientist        105-167
# 658     Data Scientist        105-167
# 659     Data Scientist        105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 655  Summary\n\nWe’re looking for a data scientist ...     3.6
# 656  Job Description\nBecome a thought leader withi...     0.0
# 657  Join a thriving company that is changing the w...     0.0
# 658  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 659  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# 1                 ManTech      Chantilly, VA             Herndon, VA
# 2          Analysis Group         Boston, MA              Boston, MA
# 3                 INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions       New York, NY            New York, NY
# ..                    ...                ...                     ...
# 655              TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 656                  JKGT  San Francisco, CA                      -1
# 657            AccessHope      Irwindale, CA                      -1
# 658  ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 659         1-800-Flowers       New York, NY         Carle Place, NY
#
#                         Size        Type of ownership  \
# 0     1001 to 5000 employees   Nonprofit Organization
# 1    5001 to 10000 employees         Company - Public
# 2     1001 to 5000 employees  Private Practice / Firm
# 3      501 to 1000 employees         Company - Public
# 4        51 to 200 employees        Company - Private
# ..                       ...                      ...
# 655   1001 to 5000 employees        Company - Private
# 656                       -1                       -1
# 657                       -1                       -1
# 658        1 to 50 employees        Company - Private
# 659   1001 to 5000 employees         Company - Public
#
#                                   Industry  ... company_age python  excel  \
# 0                       Insurance Carriers  ...          27      0      0
# 1                   Research & Development  ...          52      0      0
# 2                               Consulting  ...          39      1      1
# 3    Electrical & Electronic Manufacturing  ...          20      1      1
# 4                  Advertising & Marketing  ...          22      1      1
# ..                                     ...  ...         ...    ...    ...
# 655                Advertising & Marketing  ...          31      1      1
# 656                                     -1  ...          -1      0      0
# 657                                     -1  ...          -1      1      1
# 658                Advertising & Marketing  ...          -1      1      0
# 659                              Wholesale  ...          44      1      1
#
#      hadoop  spark aws  tableau  big_data        job_simp  seniority
# 0         0      0   1        0         0  data scientist     senior
# 1         1      0   0        0         1  data scientist         na
# 2         0      0   1        0         0  data scientist         na
# 3         0      0   1        0         0  data scientist         na
# 4         0      0   0        0         0  data scientist         na
# ..      ...    ...  ..      ...       ...             ...        ...
# 655       1      0   0        1         1  data scientist         na
# 656       0      0   0        0         0  data scientist         na
# 657       1      0   0        1         0  data scientist         na
# 658       1      1   0        0         1  data scientist         na
# 659       0      0   0        1         0  data scientist         na
#
# [660 rows x 27 columns]

# %% [markdown]
# b. Utiliza la siguiente lista de valores que serán considerados como nulos:
# ["na", "NA", -1, "0", "-1", "null", "n/a", "N/A", "NULL"]
# (hint: utiliza el método replace para reemplazar los valores indicados por np.nan)

# %%
# Primero importamos la librería que vamos a utilizar.
import numpy as np

# Creamos la lista con los valores que queremos reemplazar.
valores_a_reemplazar=["na", "NA", -1, "0", "-1", "null", "n/a", "N/A", "NULL"]

# Usamos el método replace para reemplazar los valores que consideramos como nulos en la lista anterior.
df_limpio = df.replace(to_replace=valores_a_reemplazar, value=np.nan, inplace=False)

# Visualizamos el dataframe nuevo, para comprobar que los valores se hayan reemplazado.
df_limpio
# Out:
#              Job Title Salary Estimate  \
# 0    Sr Data Scientist        137-171
# 1       Data Scientist        137-171
# 2       Data Scientist        137-171
# 3       Data Scientist        137-171
# 4       Data Scientist        137-171
# ..                 ...             ...
# 655     Data Scientist        105-167
# 656     Data Scientist        105-167
# 657     Data Scientist        105-167
# 658     Data Scientist        105-167
# 659     Data Scientist        105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 655  Summary\n\nWe’re looking for a data scientist ...     3.6
# 656  Job Description\nBecome a thought leader withi...     0.0
# 657  Join a thriving company that is changing the w...     0.0
# 658  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 659  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# 1                 ManTech      Chantilly, VA             Herndon, VA
# 2          Analysis Group         Boston, MA              Boston, MA
# 3                 INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions       New York, NY            New York, NY
# ..                    ...                ...                     ...
# 655              TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 656                  JKGT  San Francisco, CA                     NaN
# 657            AccessHope      Irwindale, CA                     NaN
# 658  ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 659         1-800-Flowers       New York, NY         Carle Place, NY
#
#                         Size        Type of ownership  \
# 0     1001 to 5000 employees   Nonprofit Organization
# 1    5001 to 10000 employees         Company - Public
# 2     1001 to 5000 employees  Private Practice / Firm
# 3      501 to 1000 employees         Company - Public
# 4        51 to 200 employees        Company - Private
# ..                       ...                      ...
# 655   1001 to 5000 employees        Company - Private
# 656                      NaN                      NaN
# 657                      NaN                      NaN
# 658        1 to 50 employees        Company - Private
# 659   1001 to 5000 employees         Company - Public
#
#                                   Industry  ... company_age python  excel  \
# 0                       Insurance Carriers  ...        27.0      0      0
# 1                   Research & Development  ...        52.0      0      0
# 2                               Consulting  ...        39.0      1      1
# 3    Electrical & Electronic Manufacturing  ...        20.0      1      1
# 4                  Advertising & Marketing  ...        22.0      1      1
# ..                                     ...  ...         ...    ...    ...
# 655                Advertising & Marketing  ...        31.0      1      1
# 656                                    NaN  ...         NaN      0      0
# 657                                    NaN  ...         NaN      1      1
# 658                Advertising & Marketing  ...         NaN      1      0
# 659                              Wholesale  ...        44.0      1      1
#
#      hadoop  spark aws  tableau  big_data        job_simp  seniority
# 0         0      0   1        0         0  data scientist     senior
# 1         1      0   0        0         1  data scientist        NaN
# 2         0      0   1        0         0  data scientist        NaN
# 3         0      0   1        0         0  data scientist        NaN
# 4         0      0   0        0         0  data scientist        NaN
# ..      ...    ...  ..      ...       ...             ...        ...
# 655       1      0   0        1         1  data scientist        NaN
# 656       0      0   0        0         0  data scientist        NaN
# 657       1      0   0        1         0  data scientist        NaN
# 658       1      1   0        0         1  data scientist        NaN
# 659       0      0   0        1         0  data scientist        NaN
#
# [660 rows x 27 columns]

# %% [markdown]
# c. Elimina todas las filas con datos faltantes. (hint: utiliza el método .dropna())

# %%
# Borramos las filas con los datos faltantes y también reseteamos los indices para que no haya saltos.
df_limpio=df_limpio.dropna().reset_index(drop=True)

# Visualizamos el df_limpio.
df_limpio
# Out:
#                                        Job Title Salary Estimate  \
# 0                              Sr Data Scientist        137-171
# 1   Senior Research Statistician- Data Scientist         75-131
# 2                  Senior Analyst/Data Scientist         75-131
# 3                          Senior Data Scientist         75-131
# 4                          Senior Data Scientist         75-131
# ..                                           ...             ...
# 75                          Senior Data Engineer        138-158
# 76                         Senior Data Scientist         80-132
# 77                         Senior Data Scientist         87-141
# 78                         Senior Data Scientist        105-167
# 79        Sr. ML/Data Scientist - AI/NLP/Chatbot        105-167
#
#                                       Job Description  Rating  \
# 0   Description\n\nThe Senior Data Scientist is re...     3.1
# 1   Acuity is seeking a Senior Research Statistici...     4.8
# 2   At Edmunds were driven to make car buying easi...     3.4
# 3   Klaviyo is looking for Senior Data Scientists ...     4.8
# 4   Benson Hill empowers innovators to develop mor...     3.5
# ..                                                ...     ...
# 75  Senior Data Engineer\n\nMaster’s degree in Inf...     2.9
# 76  Job Requisition ID #\n20WD40666\nJob Title\nSe...     4.0
# 77  Secure our Nation, Ignite your Future\n\nJob S...     4.2
# 78  About Us\n\nAt GutCheck, we pioneered agile ma...     3.8
# 79  Sr. ML/Data Scientist - AI/NLP/Chatbot\n\nMist...     3.8
#
#           Company Name           Location      Headquarters  \
# 0          Healthfirst       New York, NY      New York, NY
# 1     Acuity Insurance      Sheboygan, WI     Sheboygan, WI
# 2          Edmunds.com   Santa Monica, CA  Santa Monica, CA
# 3              Klaviyo         Boston, MA        Boston, MA
# 4          Benson Hill    Saint Louis, MO   Saint Louis, MO
# ..                 ...                ...               ...
# 75  Affinity Solutions       New York, NY      New York, NY
# 76            Autodesk  San Francisco, CA    San Rafael, CA
# 77             ManTech     Alexandria, VA       Herndon, VA
# 78            GutCheck         Denver, CO        Denver, CO
# 79    Juniper Networks      Cupertino, CA     Sunnyvale, CA
#
#                        Size       Type of ownership  \
# 0    1001 to 5000 employees  Nonprofit Organization
# 1    1001 to 5000 employees       Company - Private
# 2     501 to 1000 employees       Company - Private
# 3      201 to 500 employees       Company - Private
# 4      201 to 500 employees       Company - Private
# ..                      ...                     ...
# 75      51 to 200 employees       Company - Private
# 76  5001 to 10000 employees        Company - Public
# 77  5001 to 10000 employees        Company - Public
# 78      51 to 200 employees       Company - Private
# 79  5001 to 10000 employees        Company - Public
#
#                         Industry  ... company_age python  excel  hadoop  \
# 0             Insurance Carriers  ...        27.0      0      0       0
# 1             Insurance Carriers  ...        95.0      0      0       0
# 2                       Internet  ...        54.0      1      1       0
# 3   Computer Hardware & Software  ...         8.0      0      0       0
# 4      Biotech & Pharmaceuticals  ...         8.0      1      1       0
# ..                           ...  ...         ...    ...    ...     ...
# 75       Advertising & Marketing  ...        22.0      1      0       1
# 76  Computer Hardware & Software  ...        38.0      1      0       1
# 77        Research & Development  ...        52.0      1      0       1
# 78       Advertising & Marketing  ...        11.0      0      0       0
# 79   Telecommunications Services  ...        24.0      1      1       0
#
#     spark aws  tableau  big_data        job_simp  seniority
# 0       0   1        0         0  data scientist     senior
# 1       0   0        0         0  data scientist     senior
# 2       0   1        1         0  data scientist     senior
# 3       0   0        0         0  data scientist     senior
# 4       0   0        0         1  data scientist     senior
# ..    ...  ..      ...       ...             ...        ...
# 75      1   0        1         0   data engineer     senior
# 76      1   0        0         1  data scientist     senior
# 77      1   0        1         1  data scientist     senior
# 78      0   0        0         0  data scientist     senior
# 79      1   1        0         0  data scientist     senior
#
# [80 rows x 27 columns]

# %% [markdown]
# d. A partir de la columna “Salary Estimate”, genera dos columnas: Salario Estimado Mínimo
# y Máximo. (hint: Utiliza el método apply sobre la columna.)

# %%
# Primero definimos la función que vamos a usar. 
def parse_salary(salary_estimate):
    try:
        # Dividimos el rango por el guion '-'.
        min_salario, max_salario =salary_estimate.split('-')
        
        # Convertimos a números enteros.
        return [int(min_salario.strip()), int(max_salario.strip())]
    
    except ValueError:
        # Si la división falla (no hay guion) o la conversión a int falla.
        return [np.nan, np.nan]

# Aplicación y Expansión de Columnas.
df_limpio[['Salario Estimado Mínimo', 'Salario Estimado Máximo']] = \
    df_limpio['Salary Estimate'].apply(parse_salary).apply(pd.Series)

#Imprimimos el resultado.
df_limpio
# Out:
#                                        Job Title Salary Estimate  \
# 0                              Sr Data Scientist        137-171
# 1   Senior Research Statistician- Data Scientist         75-131
# 2                  Senior Analyst/Data Scientist         75-131
# 3                          Senior Data Scientist         75-131
# 4                          Senior Data Scientist         75-131
# ..                                           ...             ...
# 75                          Senior Data Engineer        138-158
# 76                         Senior Data Scientist         80-132
# 77                         Senior Data Scientist         87-141
# 78                         Senior Data Scientist        105-167
# 79        Sr. ML/Data Scientist - AI/NLP/Chatbot        105-167
#
#                                       Job Description  Rating  \
# 0   Description\n\nThe Senior Data Scientist is re...     3.1
# 1   Acuity is seeking a Senior Research Statistici...     4.8
# 2   At Edmunds were driven to make car buying easi...     3.4
# 3   Klaviyo is looking for Senior Data Scientists ...     4.8
# 4   Benson Hill empowers innovators to develop mor...     3.5
# ..                                                ...     ...
# 75  Senior Data Engineer\n\nMaster’s degree in Inf...     2.9
# 76  Job Requisition ID #\n20WD40666\nJob Title\nSe...     4.0
# 77  Secure our Nation, Ignite your Future\n\nJob S...     4.2
# 78  About Us\n\nAt GutCheck, we pioneered agile ma...     3.8
# 79  Sr. ML/Data Scientist - AI/NLP/Chatbot\n\nMist...     3.8
#
#           Company Name           Location      Headquarters  \
# 0          Healthfirst       New York, NY      New York, NY
# 1     Acuity Insurance      Sheboygan, WI     Sheboygan, WI
# 2          Edmunds.com   Santa Monica, CA  Santa Monica, CA
# 3              Klaviyo         Boston, MA        Boston, MA
# 4          Benson Hill    Saint Louis, MO   Saint Louis, MO
# ..                 ...                ...               ...
# 75  Affinity Solutions       New York, NY      New York, NY
# 76            Autodesk  San Francisco, CA    San Rafael, CA
# 77             ManTech     Alexandria, VA       Herndon, VA
# 78            GutCheck         Denver, CO        Denver, CO
# 79    Juniper Networks      Cupertino, CA     Sunnyvale, CA
#
#                        Size       Type of ownership  \
# 0    1001 to 5000 employees  Nonprofit Organization
# 1    1001 to 5000 employees       Company - Private
# 2     501 to 1000 employees       Company - Private
# 3      201 to 500 employees       Company - Private
# 4      201 to 500 employees       Company - Private
# ..                      ...                     ...
# 75      51 to 200 employees       Company - Private
# 76  5001 to 10000 employees        Company - Public
# 77  5001 to 10000 employees        Company - Public
# 78      51 to 200 employees       Company - Private
# 79  5001 to 10000 employees        Company - Public
#
#                         Industry  ... excel hadoop  spark  aws  tableau  \
# 0             Insurance Carriers  ...     0      0      0    1        0
# 1             Insurance Carriers  ...     0      0      0    0        0
# 2                       Internet  ...     1      0      0    1        1
# 3   Computer Hardware & Software  ...     0      0      0    0        0
# 4      Biotech & Pharmaceuticals  ...     1      0      0    0        0
# ..                           ...  ...   ...    ...    ...  ...      ...
# 75       Advertising & Marketing  ...     0      1      1    0        1
# 76  Computer Hardware & Software  ...     0      1      1    0        0
# 77        Research & Development  ...     0      1      1    0        1
# 78       Advertising & Marketing  ...     0      0      0    0        0
# 79   Telecommunications Services  ...     1      0      1    1        0
#
#    big_data        job_simp  seniority  Salario Estimado Mínimo  \
# 0         0  data scientist     senior                      137
# 1         0  data scientist     senior                       75
# 2         0  data scientist     senior                       75
# 3         0  data scientist     senior                       75
# 4         1  data scientist     senior                       75
# ..      ...             ...        ...                      ...
# 75        0   data engineer     senior                      138
# 76        1  data scientist     senior                       80
# 77        1  data scientist     senior                       87
# 78        0  data scientist     senior                      105
# 79        0  data scientist     senior                      105
#
#     Salario Estimado Máximo
# 0                       171
# 1                       131
# 2                       131
# 3                       131
# 4                       131
# ..                      ...
# 75                      158
# 76                      132
# 77                      141
# 78                      167
# 79                      167
#
# [80 rows x 29 columns]

# %% [markdown]
# e. Realiza la recodificación de la columna Size con los valores de la siguiente tabla: (hint: utilice reemplazo con diccionario usando el método replace sobre la columna.)

# %%
# Definimos el diccionario.
recodificacion = {
    '10000+ employees': 'Mega Empresas',
    '5001 to 10000 employees': 'Grandes Empresas',
    '1001 to 5000 employees': 'Medianas Empresas',
    '501 to 1000 employees': 'Microempresas', 
    '201 to 500 employees': 'Pequeñas Empresas',
    '51 to 200 employees': 'Pequeñas Grandes Empresas', 
    'Unknown': 'Empresas sin Información'
}

# Aplicamos el reemplazo.
df_limpio['Size'] = df_limpio['Size'].replace(recodificacion)

#Imprimimos el resultado.
df_limpio
# Out:
#                                        Job Title Salary Estimate  \
# 0                              Sr Data Scientist        137-171
# 1   Senior Research Statistician- Data Scientist         75-131
# 2                  Senior Analyst/Data Scientist         75-131
# 3                          Senior Data Scientist         75-131
# 4                          Senior Data Scientist         75-131
# ..                                           ...             ...
# 75                          Senior Data Engineer        138-158
# 76                         Senior Data Scientist         80-132
# 77                         Senior Data Scientist         87-141
# 78                         Senior Data Scientist        105-167
# 79        Sr. ML/Data Scientist - AI/NLP/Chatbot        105-167
#
#                                       Job Description  Rating  \
# 0   Description\n\nThe Senior Data Scientist is re...     3.1
# 1   Acuity is seeking a Senior Research Statistici...     4.8
# 2   At Edmunds were driven to make car buying easi...     3.4
# 3   Klaviyo is looking for Senior Data Scientists ...     4.8
# 4   Benson Hill empowers innovators to develop mor...     3.5
# ..                                                ...     ...
# 75  Senior Data Engineer\n\nMaster’s degree in Inf...     2.9
# 76  Job Requisition ID #\n20WD40666\nJob Title\nSe...     4.0
# 77  Secure our Nation, Ignite your Future\n\nJob S...     4.2
# 78  About Us\n\nAt GutCheck, we pioneered agile ma...     3.8
# 79  Sr. ML/Data Scientist - AI/NLP/Chatbot\n\nMist...     3.8
#
#           Company Name           Location      Headquarters  \
# 0          Healthfirst       New York, NY      New York, NY
# 1     Acuity Insurance      Sheboygan, WI     Sheboygan, WI
# 2          Edmunds.com   Santa Monica, CA  Santa Monica, CA
# 3              Klaviyo         Boston, MA        Boston, MA
# 4          Benson Hill    Saint Louis, MO   Saint Louis, MO
# ..                 ...                ...               ...
# 75  Affinity Solutions       New York, NY      New York, NY
# 76            Autodesk  San Francisco, CA    San Rafael, CA
# 77             ManTech     Alexandria, VA       Herndon, VA
# 78            GutCheck         Denver, CO        Denver, CO
# 79    Juniper Networks      Cupertino, CA     Sunnyvale, CA
#
#                          Size       Type of ownership  \
# 0           Medianas Empresas  Nonprofit Organization
# 1           Medianas Empresas       Company - Private
# 2               Microempresas       Company - Private
# 3           Pequeñas Empresas       Company - Private
# 4           Pequeñas Empresas       Company - Private
# ..                        ...                     ...
# 75  Pequeñas Grandes Empresas       Company - Private
# 76           Grandes Empresas        Company - Public
# 77           Grandes Empresas        Company - Public
# 78  Pequeñas Grandes Empresas       Company - Private
# 79           Grandes Empresas        Company - Public
#
#                         Industry  ... hadoop spark  aws  tableau  big_data  \
# 0             Insurance Carriers  ...      0     0    1        0         0
# 1             Insurance Carriers  ...      0     0    0        0         0
# 2                       Internet  ...      0     0    1        1         0
# 3   Computer Hardware & Software  ...      0     0    0        0         0
# 4      Biotech & Pharmaceuticals  ...      0     0    0        0         1
# ..                           ...  ...    ...   ...  ...      ...       ...
# 75       Advertising & Marketing  ...      1     1    0        1         0
# 76  Computer Hardware & Software  ...      1     1    0        0         1
# 77        Research & Development  ...      1     1    0        1         1
# 78       Advertising & Marketing  ...      0     0    0        0         0
# 79   Telecommunications Services  ...      0     1    1        0         0
#
#           job_simp  seniority  Salario Estimado Mínimo  \
# 0   data scientist     senior                      137
# 1   data scientist     senior                       75
# 2   data scientist     senior                       75
# 3   data scientist     senior                       75
# 4   data scientist     senior                       75
# ..             ...        ...                      ...
# 75   data engineer     senior                      138
# 76  data scientist     senior                       80
# 77  data scientist     senior                       87
# 78  data scientist     senior                      105
# 79  data scientist     senior                      105
#
#     Salario Estimado Máximo          Size_Recodificado
# 0                       171          Medianas Empresas
# 1                       131          Medianas Empresas
# 2                       131              Microempresas
# 3                       131          Pequeñas Empresas
# 4                       131          Pequeñas Empresas
# ..                      ...                        ...
# 75                      158  Pequeñas Grandes Empresas
# 76                      132           Grandes Empresas
# 77                      141           Grandes Empresas
# 78                      167  Pequeñas Grandes Empresas
# 79                      167           Grandes Empresas
#
# [80 rows x 30 columns]

# %% [markdown]
# f. Finalmente, genera una tabla pivote que muestre la media del salario estimado mínimo y la media del salario estimado máximo por tamaño de empresa. (hint: utiliza pd.pivot_table para generar la vista adecuada con las columnas generadas.)

# %%
# Generamos la tabla pivote.
df_salario= pd.pivot_table(
    data=df_limpio,
    index='Size',
    values=['Salario Estimado Mínimo', 'Salario Estimado Máximo'],
    aggfunc='mean',  # Indicamos que queremos el promedio.
)

# Para mejorar la lectura quitamos los decimales.
df_salario = df_salario.round(0).astype(int)

#Imprimimos el resultado.
print("\nTabla Pivote: Salario Promedio por Tamaño de Empresa:")
df_salario
# Out:
# Tabla Pivote: Salario Promedio por Tamaño de Empresa:
#                            Salario Estimado Máximo  Salario Estimado Mínimo
# Size
# Empresas sin Información                       110                       73
# Grandes Empresas                               139                       92
# Medianas Empresas                              137                       94
# Mega Empresas                                  151                       98
# Microempresas                                  146                      100
# Pequeñas Empresas                              141                       94
# Pequeñas Grandes Empresas                      138                      101
